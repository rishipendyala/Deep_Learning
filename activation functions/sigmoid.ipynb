# %% [markdown]
# # Sigmoid

# %% [markdown]
# ## 🧠 Sigmoid Activation Function
#
# The **Sigmoid function**, also known as the **logistic function**, maps any real-valued input into a range between **0 and 1**.
# It is defined as:
#
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}
# $$
#
# ---
#
# ### 📊 Intuition
#
# - For large positive inputs, the output approaches **1**.
# - For large negative inputs, the output approaches **0**.
# - Around **x = 0**, the function changes rapidly — this is where gradients are strongest.
#
# Sigmoid effectively **squashes** input values into a narrow range, making it useful for probabilistic outputs.
#
# ---
#
# ### ✅ Use Cases
#
# - **Binary classification (output layer)** — converts logits into probabilities.
# - **Logistic regression** — the backbone of logistic models.
# - **Early neural networks** — used in hidden layers before ReLU and Tanh gained popularity.
# - **Probabilistic interpretation** — helps interpret model confidence for binary outcomes.
#
# ---
#
# ### 🌟 Advantages
#
# - Smooth and **differentiable everywhere**, enabling gradient-based optimization.
# - Output lies in **(0, 1)** — ideal for representing probabilities.
# - **Monotonic** — ensures consistent ordering of inputs and outputs.
# - **Simple mathematical form** — easy to compute and interpret.
#
# ---
#
# ### ⚠️ Disadvantages
#
# - **Vanishing gradient problem:** gradients become very small for large or small input values, slowing learning.
# - **Not zero-centered:** all outputs are positive, which can cause inefficient weight updates.
# - **Saturates at extremes:** for large |x|, output ≈ 0 or 1 → very small gradient.
# - **Slightly more computationally expensive** due to the exponential operation.
#
# ---
#
# ### 📈 Derivative
#
# The derivative of the sigmoid is simple and elegant:
#
# $$
# \sigma'(x) = \sigma(x) \times (1 - \sigma(x))
# $$

# %% [markdown]
# ## Implementation and Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 100)
y = 1 / (1 + np.exp(-x))
y_derivative = y * (1 - y)

plt.plot(x, y, label='sigmoid(x)')
plt.plot(x, y_derivative, label="sigmoid'(x)")
plt.title('Sigmoid Function and its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()

# %%
import torch
import torch.nn as nn

class SimpleNeuralNetwork(nn.Module):
    def __init__(self):
        super(SimpleNeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(748,128)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 10)
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x
    
model = SimpleNeuralNetwork()
input_tensor = torch.randn(32,748)
output = model(input_tensor)

print(f"output.shape: {output.shape}")
print(f"output: {output}")
# Out:
# output.shape: torch.Size([32, 10])
# output: tensor([[-4.8499e-02,  9.8605e-02,  6.2807e-01, -1.4223e-01,  2.8807e-01,
#           1.2039e-01, -1.7486e-01,  1.5808e-01, -3.0819e-02,  4.3120e-02],
#         [-2.8580e-01, -1.1509e-02, -2.0277e-02, -2.7919e-01,  1.7676e-01,
#           3.0491e-01,  2.0193e-01,  6.4580e-02,  2.7984e-01,  1.5474e-01],
#         [ 1.1507e-01,  2.8629e-01,  2.2370e-01,  9.2584e-02,  1.7318e-01,
#           5.5549e-01, -4.6088e-02,  5.4054e-02,  3.9187e-01,  8.3225e-02],
#         [-1.9254e-01,  1.0964e-01,  1.0012e-01, -3.5872e-03,  3.0694e-01,
#           2.1360e-01,  3.5229e-01,  1.4145e-01,  3.1847e-01,  1.4632e-01],
#         [ 2.1255e-01,  2.5169e-01,  6.0006e-01,  2.8204e-02, -5.7803e-03,
#           2.6736e-01, -2.7095e-01, -1.9022e-01,  2.7266e-01,  2.6825e-02],
#         [-2.3075e-01, -5.1711e-02,  4.1758e-01, -5.6931e-02, -5.3613e-02,
#           2.7247e-02, -3.4656e-02,  1.0255e-01, -1.1053e-02, -5.1970e-02],
# ...
